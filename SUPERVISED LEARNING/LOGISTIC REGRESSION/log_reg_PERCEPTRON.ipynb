# %% [markdown]
# <a href="https://colab.research.google.com/github/VIHAN-droid/AI-ML-PROJECT/blob/main/SUPERVISED%20LEARNING/LOGISTIC%20REGRESSION/log_reg_PERCEPTRON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
x,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=4,hypercube=False,class_sep=10)
plt.scatter(x[:,0] , x[:,1] ,c = y)

# %%
def perceptron(x,y,learning_rate,epochs):
  x = np.insert(x,0,1,axis=1)
  coeff = np.ones(x.shape[1])

  for _ in range(epochs):
    i = np.random.randint(0,x.shape[0])
    a = np.dot(coeff,x[i])
    if a>0:
      a = 1
    else:
      a = 0
    coeff = coeff + learning_rate * (y[i] - a) * x[i]

  return coeff[0] , coeff[1:]

# %%
intercept , coefficients = perceptron(x,y,0.1,1000)
print(intercept , coefficients)
# Out:
# 1.0 [1. 1.]

# %%
m = - (coefficients[0] / coefficients[1])
c = - (intercept / coefficients[1])
x_plot = np.linspace(-3,2,100)
y_plot = m * x_plot + c
plt.plot(x_plot,y_plot,color="red")
plt.scatter(x[:,0],x[:,1],c=y)

# %% [markdown]
# # LOGISTIC REGRESSION FROM SKLEARN

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(x,y)
# Out:
# LogisticRegression()

# %%
m = - (lor.coef_[0][0] / lor.coef_[0][1])
c = - (lor.intercept_[0] / lor.coef_[0][1])
x_plot2 = np.linspace(-3,2,100)
y_plot2 = m * x_plot + c
plt.plot(x_plot2,y_plot2,color="red",label="SkLearn")
plt.plot(x_plot,y_plot,color="blue",label="Perceptron")
plt.legend()
plt.scatter(x[:,0],x[:,1],c=y)

# thus sklearn's model cuts the graph symmetrically whereas perceptron stops after classifyong the points accurately
